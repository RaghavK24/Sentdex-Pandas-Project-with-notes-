# %%
import pandas as pd
df = pd.read_csv(r"C:/Users/Lenovo/Desktop/datasets/Minimum Wage Data.csv", encoding="latin")
df.to_csv("C:/Users/Lenovo/Desktop/datasets/MinWage.csv", encoding="utf-8")

# %% [markdown]
# ![Screenshot%202022-08-12%20202651.png](attachment:Screenshot%202022-08-12%20202651.png)

# %% [markdown]
# # We do this because the encoding in latin makes our problem error prone so we change it to utf-8

# %%
df = pd.read_csv(r"C:/Users/Lenovo/Desktop/datasets/MinWage.csv")
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...

# %%
gb=df.groupby("State")
gb.get_group("Alabama").set_index("Year").head()
# Out:
#       Unnamed: 0    State  State.Minimum.Wage  \
# Year
# 1968           0  Alabama                 0.0
# 1969          54  Alabama                 0.0
# 1970         108  Alabama                 0.0
# 1971         162  Alabama                 0.0
# 1972         216  Alabama                 0.0
#
#       State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# Year
# 1968                              0.0                  1.15
# 1969                              0.0                  1.15
# 1970                              0.0                  1.30
# 1971                              0.0                  1.30
# 1972                              0.0                  1.60
#
#       Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# Year
# 1968                               8.55                    1.15
# 1969                               8.11                    1.15
# 1970                               8.67                    1.30
# ...

# %% [markdown]
# # This is just for understanding, we create gb which is grouped by state and in the below program the name refers to name of the state and group refers to the whole dataframe or 'gb' itself.
#
# ## https://www.geeksforgeeks.org/python-pandas-dataframe-groupby/

# %%
act_min_wage = pd.DataFrame()

for name, group in gb:
    if act_min_wage.empty:
        act_min_wage = group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name})
    else:
        act_min_wage = act_min_wage.join(group.set_index("Year")[["Department.Of.Labor.Cleaned.Low.Value.2020.Dollars"]].rename(columns={"Department.Of.Labor.Cleaned.Low.Value.2020.Dollars":name}))

act_min_wage.head()
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.61     3.48      1.16       12.26      7.43        10.41
# 1969      0.0   14.80     3.30      1.10       11.63      7.05         9.87
# 1970      0.0   14.00     3.12      7.33       11.00      6.67        10.67
# 1971      0.0   13.41     2.99      7.03       10.54      6.39        10.22
# 1972      0.0   12.99     2.90      7.43       10.21      6.19        11.45
#
#       Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                           ...
# 1968      9.29                  9.29      0.0  ...        0.0   0.00
# 1969      8.81                  8.81      0.0  ...        0.0   0.00
# 1970      8.33                 10.67      0.0  ...        0.0   0.00
# 1971      7.98                 10.22      0.0  ...        0.0   0.00
# 1972      9.90                  9.90      0.0  ...        0.0   8.66
#
# ...

# %% [markdown]
# # This is another way to get a table with specific iterations such as low cleaned values with date as index and states as columns

# %%
pd.pivot_table(df, values="Department.Of.Labor.Cleaned.Low.Value.2020.Dollars", index="Year", columns='State').head()
# Out:
# State  Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968       0.0   15.61     3.48      1.16       12.26      7.43        10.41
# 1969       0.0   14.80     3.30      1.10       11.63      7.05         9.87
# 1970       0.0   14.00     3.12      7.33       11.00      6.67        10.67
# 1971       0.0   13.41     2.99      7.03       10.54      6.39        10.22
# 1972       0.0   12.99     2.90      7.43       10.21      6.19        11.45
#
# State  Delaware  District of Columbia  Florida  ...  Tennessee  Texas  \
# Year                                            ...
# 1968       9.29                  9.29      0.0  ...        0.0   0.00
# 1969       8.81                  8.81      0.0  ...        0.0   0.00
# 1970       8.33                 10.67      0.0  ...        0.0   0.00
# 1971       7.98                 10.22      0.0  ...        0.0   0.00
# 1972       9.90                  9.90      0.0  ...        0.0   8.66
#
# ...

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     53.0  53.000000  53.000000  53.000000   53.000000  53.000000
# mean       0.0   9.917736   2.917358   7.139245    9.101132   6.881698
# std        0.0   1.852213   4.102247   1.459132    1.418712   1.921086
# min        0.0   7.620000   0.000000   1.100000    6.630000   3.970000
# 25%        0.0   8.590000   0.000000   6.780000    8.000000   5.250000
# 50%        0.0   9.260000   0.000000   7.210000    9.010000   6.670000
# 75%        0.0  10.510000   8.290000   7.740000    9.710000   8.430000
# max        0.0  15.610000  12.140000  10.000000   13.000000  12.140000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      9.212830   7.818679              8.919245   2.415283  ...
# std       1.106907   1.307834              1.932959   3.882305  ...
# ...

# %% [markdown]
# # The correlation coefficient is a statistical measure of the strength of the relationship between the relative movements of two variables. The values range between -1.0 and 1.0. A calculated number greater than 1.0 or less than -1.0 means that there was an error in the correlation measurement. A correlation of -1.0 shows a perfect negative correlation, while a correlation of 1.0 shows a perfect positive correlation. A correlation of 0.0 shows no linear relationship between the movement of the two variables.
#
# # Correlation statistics can be used in finance and investing. For example, a correlation coefficient could be calculated to determine the level of correlation between the price of crude oil and the stock price of an oil-producing company, such as Exxon Mobil Corporation. Since oil companies earn greater profits as oil prices rise, the correlation between the two variables is highly positive.

# %%
act_min_wage.corr().head()
# Out:
#             Alabama    Alaska   Arizona  Arkansas  California  Colorado  \
# Alabama         NaN       NaN       NaN       NaN         NaN       NaN
# Alaska          NaN  1.000000  0.037101 -0.332127    0.622245 -0.078678
# Arizona         NaN  0.037101  1.000000  0.271834    0.639006  0.820730
# Arkansas        NaN -0.332127  0.271834  1.000000    0.030265  0.333597
# California      NaN  0.622245  0.639006  0.030265    1.000000  0.649967
#
#             Connecticut  Delaware  District of Columbia   Florida  ...  \
# Alabama             NaN       NaN                   NaN       NaN  ...
# Alaska         0.646909  0.260265              0.271810 -0.193062  ...
# Arizona        0.555455  0.477781              0.723523  0.907295  ...
# Arkansas       0.183662  0.107639              0.433775  0.340509  ...
# California     0.881831  0.518481              0.727373  0.443946  ...
#
#             Tennessee     Texas  U.S. Virgin Islands      Utah   Vermont  \
# ...

# %% [markdown]
# # We can see that many of these have NaN datas, this is when the data is not available for these values. Look at the original U.S. Government data from which this is taken. We can see that the data there is just '...', which when we look at the df.head() the author of the dataset at kaggle has just replaced them with 0
#
# ![Screenshot%20%285%29.png](attachment:Screenshot%20%285%29.png)

# %%
df.head()
# Out:
#    Unnamed: 0  Year       State  State.Minimum.Wage  \
# 0           0  1968     Alabama             0.00000
# 1           1  1968      Alaska             2.10000
# 2           2  1968     Arizona             0.46800
# 3           3  1968    Arkansas             0.15625
# 4           4  1968  California             1.65000
#
#    State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                             0.00                  1.15
# 1                            15.61                  1.15
# 2                             3.48                  1.15
# 3                             1.16                  1.15
# 4                            12.26                  1.15
#
#    Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                               8.55                    1.15
# 1                               8.55                    2.10
# 2                               8.55                    1.15
# ...

# %%
issue_df = df[df['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars']==0]

issue_df.head()
# Out:
#     Unnamed: 0  Year     State  State.Minimum.Wage  \
# 0            0  1968   Alabama                 0.0
# 9            9  1968   Florida                 0.0
# 10          10  1968   Georgia                 0.0
# 14          14  1968  Illinois                 0.0
# 16          16  1968      Iowa                 0.0
#
#     State.Minimum.Wage.2020.Dollars  Federal.Minimum.Wage  \
# 0                               0.0                  1.15
# 9                               0.0                  1.15
# 10                              0.0                  1.15
# 14                              0.0                  1.15
# 16                              0.0                  1.15
#
#     Federal.Minimum.Wage.2020.Dollars  Effective.Minimum.Wage  \
# 0                                8.55                    1.15
# 9                                8.55                    1.15
# 10                               8.55                    1.15
# ...

# %% [markdown]
# # Now if we look at the states which have 0 data, we look that there are states where data for all years is 0 like in the case of alabama and some where there are only some years where the data is 0 like in the case of texas

# %%
issue_df['State'].unique()
# Out:
# array(['Alabama', 'Florida', 'Georgia', 'Illinois', 'Iowa', 'Kansas',
#        'Louisiana', 'Mississippi', 'Missouri', 'Montana',
#        'South Carolina', 'Tennessee', 'Texas', 'Virginia', 'Arizona'],
#       dtype=object)

# %% [markdown]
# # Here all 0 are replaced with NaN in the table and all the Na's are dropped. Now as we have written axis=1, only the column gets deleted (like alabama, florida and all the states which had a 0 in their data), if we did axis=0 the data of other states in the row would also be deleted which we dont want

# %%
import numpy as np

# axis 1 == columns. 0,default, is for rows
act_min_wage.replace(0, np.NaN).dropna(axis=1).corr().head()
# Out:
#                Alaska  Arkansas  California  Colorado  Connecticut  Delaware  \
# Alaska       1.000000 -0.332127    0.622245 -0.078678     0.646909  0.260265
# Arkansas    -0.332127  1.000000    0.030265  0.333597     0.183662  0.107639
# California   0.622245  0.030265    1.000000  0.649967     0.881831  0.518481
# Colorado    -0.078678  0.333597    0.649967  1.000000     0.520931  0.581162
# Connecticut  0.646909  0.183662    0.881831  0.520931     1.000000  0.586472
#
#              District of Columbia      Guam    Hawaii     Idaho  ...  \
# Alaska                   0.271810  0.787515  0.630212  0.371745  ...
# Arkansas                 0.433775  0.037006  0.324870  0.008276  ...
# California               0.727373  0.411729  0.610784  0.542006  ...
# Colorado                 0.798145 -0.152291  0.291995  0.436981  ...
# Connecticut              0.700081  0.587469  0.674581  0.536894  ...
#
#                Oregon  Pennsylvania  Rhode Island  South Dakota      Utah  \
# ...

# %% [markdown]
# # if we add how="all" , only those which have all of their values like alabama deleted, whereas texas would not be deleted which has only some zeroes

# %%
act_min_wage.replace(0, np.NaN).dropna(axis=1,how="all").corr().head()
# Out:
#               Alaska   Arizona  Arkansas  California  Colorado  Connecticut  \
# Alaska      1.000000 -0.679409 -0.332127    0.622245 -0.078678     0.646909
# Arizona    -0.679409  1.000000  0.634617    0.251150  0.948882     0.027277
# Arkansas   -0.332127  0.634617  1.000000    0.030265  0.333597     0.183662
# California  0.622245  0.251150  0.030265    1.000000  0.649967     0.881831
# Colorado   -0.078678  0.948882  0.333597    0.649967  1.000000     0.520931
#
#             Delaware  District of Columbia   Florida   Georgia  ...  \
# Alaska      0.260265              0.271810  0.244115 -0.047073  ...
# Arizona     0.077845              0.643202  0.166732 -0.806048  ...
# Arkansas    0.107639              0.433775  0.259277 -0.039566  ...
# California  0.518481              0.727373  0.273844  0.065646  ...
# Colorado    0.581162              0.798145  0.380301  0.250336  ...
#
#             South Dakota     Texas  U.S. Virgin Islands      Utah   Vermont  \
# ...

# %%
min_wage_corr = act_min_wage.replace(0, np.NaN).dropna(axis=1,how="all").corr()

# %% [markdown]
# # As we can see that for alabama the sum of all datas are 0, so we can check the above by seeking out if any state has sum of zero

# %%
grouped_issues = issue_df.groupby("State")
grouped_issues.get_group("Alabama")['Department.Of.Labor.Cleaned.Low.Value.2020.Dollars'].sum()
# Out:
# 0.0

# %%
n=0
# We put f"{states}" because there is not specific states column in min_wage_corr, hence we to apply the states name (socho)

for states in min_wage_corr.columns :
    if min_wage_corr[f"{states}"].sum() == 0 :
        n += 1
    else :
        pass

if n == 0 :
    print("There is no problem")
else :
    print("There seems to be a problem")
# Out:
# There is no problem
